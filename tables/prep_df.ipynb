# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("2021AP.xlsx")

# %%
df.drop(index = len(df['Team']) - 1, inplace = True)

# %%
df
# Out:
#                     Team Week Rank  W  L Winning Percentage Opp. Rank Opp. P5  \
# 0                Alabama    1    1  0  0                  1        14       1
# 1               Oklahoma    1    2  0  0                  1        26       0
# 2                Clemson    1    3  0  0                  1         5       1
# 3             Ohio State    1    4  0  0                  1        26       1
# 4                Georgia    1    5  0  0                  1         3       1
# ..                   ...  ...  ... .. ..                ...       ...     ...
# 245     Coastal Carolina   10   21  7  1                NaN       NaN     NaN
# 246           Penn State   10   22  5  3                NaN       NaN     NaN
# 247                  SMU   10   23  7  1                NaN       NaN     NaN
# 248  Louisiana-Lafayette   10   24  7  1                NaN       NaN     NaN
# 249         Fresno State   10   25  7  2                NaN       NaN     NaN
#
#     Home Result Points Scored Points Against Margin Next Week Rank Movement
# 0      0      W            44             13     31              1        0
# 1      1      W            40             35      5              4       -2
# 2      0      L             3             10     -7              6       -3
# 3      0      W            45             31     14              3        1
# 4      0      W            10              3      7              2        3
# ..   ...    ...           ...            ...    ...            ...      ...
# 245  NaN    NaN           NaN            NaN    NaN            NaN      NaN
# 246  NaN    NaN           NaN            NaN    NaN            NaN      NaN
# 247  NaN    NaN           NaN            NaN    NaN            NaN      NaN
# 248  NaN    NaN           NaN            NaN    NaN            NaN      NaN
# 249  NaN    NaN           NaN            NaN    NaN            NaN      NaN
#
# [250 rows x 15 columns]

# %%
week_num = max(pd.to_numeric(df['Week']))
week_num
# Out:
# 10

# %%
for team in df['Team']:
    for week in range(1, week_num + 1):
        if df.loc[(df["Team"] == team) & (df["Week"] == week)].size == 0:
            df.loc[len(df.index)] = [team, week, 26, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]

# %%
df
# Out:
#            Team Week Rank    W    L Winning Percentage Opp. Rank Opp. P5 Home  \
# 0       Alabama    1    1    0    0                  1        14       1    0
# 1      Oklahoma    1    2    0    0                  1        26       0    1
# 2       Clemson    1    3    0    0                  1         5       1    0
# 3    Ohio State    1    4    0    0                  1        26       1    0
# 4       Georgia    1    5    0    0                  1         3       1    0
# ..          ...  ...  ...  ...  ...                ...       ...     ...  ...
# 455     Houston    5   26  NaN  NaN                NaN       NaN     NaN  NaN
# 456     Houston    6   26  NaN  NaN                NaN       NaN     NaN  NaN
# 457     Houston    7   26  NaN  NaN                NaN       NaN     NaN  NaN
# 458     Houston    8   26  NaN  NaN                NaN       NaN     NaN  NaN
# 459     Houston    9   26  NaN  NaN                NaN       NaN     NaN  NaN
#
#     Result Points Scored Points Against Margin Next Week Rank Movement
# 0        W            44             13     31              1        0
# 1        W            40             35      5              4       -2
# 2        L             3             10     -7              6       -3
# 3        W            45             31     14              3        1
# 4        W            10              3      7              2        3
# ..     ...           ...            ...    ...            ...      ...
# 455    NaN           NaN            NaN    NaN            NaN      NaN
# 456    NaN           NaN            NaN    NaN            NaN      NaN
# 457    NaN           NaN            NaN    NaN            NaN      NaN
# 458    NaN           NaN            NaN    NaN            NaN      NaN
# 459    NaN           NaN            NaN    NaN            NaN      NaN
#
# [460 rows x 15 columns]

# %%
df.to_csv(f'thru_week_{week_num}.csv', header = True, index = False)
