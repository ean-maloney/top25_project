# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
#Parameters
file = "../tables/2021AP.xlsx"
next_week = 8
drop = "Margin"

#Read in df
df = pd.read_excel(file)
df
# Out:
#                     Team  Week  Rank  W  L  Winning Percentage  Opp. Rank  \
# 0                Alabama     1     1  0  0                   1         14
# 1               Oklahoma     1     2  0  0                   1         26
# 2                Clemson     1     3  0  0                   1          5
# 3             Ohio State     1     4  0  0                   1         26
# 4                Georgia     1     5  0  0                   1          3
# ..                   ...   ...   ... .. ..                 ...        ...
# 246           Penn State    10    22  5  3                 NaN        NaN
# 247                  SMU    10    23  7  1                 NaN        NaN
# 248  Louisiana-Lafayette    10    24  7  1                 NaN        NaN
# 249         Fresno State    10    25  7  2                 NaN        NaN
# 250                 Team  Week  Rank  W  L  Winning Percentage  Opp. Rank
#
#      Opp. P5  Home  Result  Points Scored  Points Against  Margin  \
# ...

# %%
#Drop footer
df.drop(index = (df.index.stop - 1), inplace = True)

#Drop null columns (teams with byes)
df.dropna(inplace = True)

#Set week
for index, row in df.iterrows():
    if row['Week'] >= next_week:
        df.drop(index = index, inplace = True)

# %%
for index, row in df.iterrows():
    if row['Result'] == 'W':
        df.at[index, 'Result'] = 1
    else: 
        df.at[index, 'Result'] = 0

# %%
df = df.drop(columns = ["Movement", "Team", drop])
#df = df.drop(columns = ["Movement", "Team"])

# %%
for name, values in df.iteritems():
    df[name] = pd.to_numeric(values)
    
df.dtypes
# Out:
# Week                    int64
# Rank                    int64
# W                       int64
# L                       int64
# Winning Percentage    float64
# Opp. Rank               int64
# Opp. P5                 int64
# Home                    int64
# Result                  int64
# Points Scored           int64
# Points Against          int64
# Next Week Rank          int64
# dtype: object

# %%
X = df.drop(columns = ['Next Week Rank'])
y = df["Next Week Rank"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 8)
X_train.shape
# Out:
# (120, 11)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#Multiple Linear Regression
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression().fit(X_train, y_train)
mlr = lin_model.score(X_test, y_test)

# %%
#Scaled Multiple Linear Regression
from sklearn.linear_model import LinearRegression
scaled_lin_model = LinearRegression().fit(X_train_scaled, y_train)
smlr = scaled_lin_model.score(X_test_scaled, y_test)

# %%
#RF
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(random_state = 8)
rf_model.fit(X_train, y_train)
rf = rf_model.score(X_test, y_test)

# %%
#Scaled RF
from sklearn.ensemble import RandomForestRegressor
scaled_rf_model = RandomForestRegressor(random_state = 8)
scaled_rf_model.fit(X_train_scaled, y_train)
srf = scaled_rf_model.score(X_test_scaled, y_test)

# %%
#AdaBoost Regression
from sklearn.ensemble import AdaBoostRegressor as abreg
ab_model = abreg(random_state = 8).fit(X_train, y_train)
abr = ab_model.score(X_test, y_test)

# %%
#Scaled AdaBoost Regression
from sklearn.ensemble import AdaBoostRegressor as abreg
scaled_ab_model = abreg(random_state = 8).fit(X_train_scaled, y_train)
sabr = scaled_ab_model.score(X_test_scaled, y_test)

# %%
print(f'Week {next_week} Model Scores - Dropping: {drop}\nMLR: {mlr}\nSMLR: {smlr}\nRF: {rf}\nSRF: {srf}\nABR: {abr}\nSABR: {sabr}')
#print(f'Week {next_week} Model Scores - Dropping: None\nMLR: {mlr}\nSMLR: {smlr}\nRF: {rf}\nSRF: {srf}\nABR: {abr}\nSABR: {sabr}')
# Out:
# Week 8 Model Scores - Dropping: Margin
# MLR: 0.9559531117411088
# SMLR: 0.9559531117411091
# RF: 0.9516002247958852
# SRF: 0.9519031201668885
# ABR: 0.9181748896085844
# SABR: 0.9183095743561381
