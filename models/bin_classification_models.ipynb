# %%
import pandas as pd
import experimental_models as em

# %%
bin_params = {}
bin_params['feature_drop'] = ['Movement', 'Team', 'Points Scored']

# %%
next_week = 13
df = em.data_prep(next_week)
df
# Out:
#                     Team Week Rank  W  L Winning Percentage Opp. Rank Opp. P5  \
# 0                Alabama    1    1  0  0                  1        14       1
# 1               Oklahoma    1    2  0  0                  1        26       0
# 2                Clemson    1    3  0  0                  1         5       1
# 3             Ohio State    1    4  0  0                  1        26       1
# 4                Georgia    1    5  0  0                  1         3       1
# ..                   ...  ...  ... .. ..                ...       ...     ...
# 295             Arkansas   12   21  7  3                0.7       NaN     NaN
# 296  Louisiana-Lafayette   12   22  9  1                0.9       NaN     NaN
# 297      San Diego State   12   23  9  1                0.9       NaN     NaN
# 298                 Utah   12   24  7  3                0.7       NaN     NaN
# 299             NC State   12   25  7  3                0.7       NaN     NaN
#
# ...

# %%
a, b, c = em.run_bin(bin_params, df, get_table = True, model = 'forest')

# %%
print(a, b)
# Out:
# 0.7301587301587301 0.30158730158730157

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
c
# Out:
#     Predictions  Actual
# 0             2       2
# 1             3       3
# 2             0       1
# 3             2       4
# 4             0       0
# 5             1       1
# 6             1       1
# 7             1       1
# 8             3       3
# 9             0       2
# 10            4       4
# 11            1       1
# 12            1       1
# 13            1       2
# 14            1       1
# 15            5       5
# 16            1       1
# 17            1       1
# 18            0       1
# 19            3       2
# 20            0       0
# 21            0       0
# 22            3       2
# 23            4       4
# 24            1       1
# 25            0       0
# 26            1       2
# 27            0       0
# 28            1       1
# 29            0       0
# 30            1       0
# 31            0       0
# 32            5       5
# 33            0       0
# 34            2       2
# 35            4       4
# 36            3       2
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(c['Actual'], c['Predictions'])
# Out:
# 0.7301587301587301
